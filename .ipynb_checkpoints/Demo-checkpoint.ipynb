# %%
import pandas as pd

# %%
# !ls
# Out:
# GeneralEsportData.csv    UI_Ideas                 ecommerce.csv
# HistoricalEsportData.csv Untitled.ipynb

# %%
df = pd.read_csv('GeneralEsportData.csv', encoding='cp1252')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558 entries, 0 to 557
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Game              558 non-null    object
#  1   ReleaseDate       558 non-null    int64
#  2   Genre             558 non-null    object
#  3   TotalEarnings     558 non-null    float64
#  4   OnlineEarnings    558 non-null    float64
#  5   TotalPlayers      558 non-null    int64
#  6   TotalTournaments  558 non-null    int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 30.6+ KB

# %%
df.head(20)
df = df.sort_values('ReleaseDate')

# %%
df.tail(20)
# Out:
#                                     Game  ReleaseDate  \
# 266                     Kirby Fighters 2         2020
# 3                      Age of Empires IV         2021
# 554                        Knockout City         2021
# 123                          Lemnis Gate         2021
# 181         League of Legends: Wild Rift         2021
# 186                        Pokemon Unite         2021
# 25                           Legion TD 2         2021
# 391                       Hot Lap League         2021
# 381                      Forza Horizon 5         2021
# 85                Call of Duty: Vanguard         2021
# 276              Mighty Fight Federation         2021
# 370  Virtua Fighter 5: Ultimate Showdown         2021
# 451                              FIFA 22         2021
# 355                     Tough Love Arena         2021
# 171                            Crab Game         2021
# 304                      Rushdown Revolt         2021
# ...

# %% [markdown]
# ### Questions

# %% [markdown]
# 1- Top Genres - Highest Average Earnings per each Tourment
#
# 2- Top Games - Highest Average Earnings per each Tourment
#
# 3- Hishest Average Player Earning per each tourment
#
# 4- Top genres in online earnings
#
# 5- Top games in online earnings
#
# 6- What is the genre that has the biggest total tourments

# %% [markdown]
# #### Filtration

# %% [markdown]
# 1- Using Release Date - filter by year - Drop down
#
# 2- Using Genre Type - Drop down

# %% [markdown]
# #### Plots Demos
